# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

torch.__version__
# Out:
# '1.5.0'

# %% [markdown]
# ## Artificial Neural Network Logistic Regression
#
#
# * Artificial Neutral Networks are biologically  inspired mathematical objects that use function composition to approximate any computable function.
#
# #### Components
#
# * Architecture
#     - Layers: Contain nodes
#     - Weights: link nodes in the layers
# * Forward Pass
#     - Function Composition: * Moving forward from input layer to output layer producing target value(s)
#     - Activation functions (non-linearity)
#
# * Backward Pass
#     - Loss Function
#         - Compare output with label, difference is the amount of error
#         - Squared Loss
#         - Cross-entropy loss
#     - Back propagation: Propagate the error backwards through the network
#     - Optimizers adjusting the weights

# %% [markdown]
# ### Architecture (Multilayer Perceptron)
#
# #### Fully-connected Feedforward Nework
#
# * A node at each layer to connected to all the nodes in the next layer.
#
# * No connections within a layer
#
#
# ![](Perceptron1.png)
# $$\text{Figure 1. Rosenblatt's Perceptron}$$
#
#
# ![](MLP1.png)
# $$\text{Figure 2. Multilayer Perceptron}$$

# %% [markdown]
# * Input layer
#     - m features, ${x_i, i = 1,...,m}$
#     - One input node per feature
# * Hidden Layer
#     - Each layer transforms via an **activation** function f the weighted sum of its input $a_i = f(\sum x_iw_i)$
#     - Width of layer is number of nodes in layer
#     - Depth of network is number of layers
#     - Layers can have different activation functions
# * Output Layer
#     - Final transformation to target outcome

# %% [markdown]
# ### Activation functions
#
# #### Sigmoid (Logistic)
#
# * Range (0,1)
#
# <div style="font-size: 115%;">
# $$\sigma(z) = \frac{1}{1 + e^{-z}}$$
# </div>
#
# * Derivative
#
# <div style="font-size: 115%;">
# $$ \frac{d}{dz}\sigma(z) = -(1 + e^{-z})^{-2}(-e^{-z}) =  \frac{1}{1 + e^{-z}}\left(1 - \frac{1}{1 + e^{-z}}\right) =  \sigma(z)(1 - \sigma(z))$$
# </div>

# %%
def Sigmoid(z):
    return 1/(1+np.exp(-z))
# Derivative of Sigmoid or Logistic function
def D_Sigmoid(z): 
    s = Sigmoid(z)
    return s * (1 - s)
z = np.linspace(-10,10,100)
fig,(ax1,ax2) = plt.subplots(1,2)
ax1.plot(z,Sigmoid(z))
ax1.set_title('Sigmoid(z)')
ax2.plot(z,D_Sigmoid(z))
ax2.set_title('Derivative of Sigmoid');

# %% [markdown]
# * Non-linear
# * In domain (-3, +3) it is very steep, pushing y values to the extremes
#     - Good for classification
# * Outside of (-3,+3) gradient is very small (vanishes)
# * Range of sigmoid is (0,1) therefore not symmetric around 0
#     - Only positive outputs which is not always desirable

# %% [markdown]
# #### Hyperbolic Tangent
#
# * Range is (-1,1)
#
# <div style="font-size: 115%;">
# $$ tanh(z) = \frac{sinh(z)}{cosh(z)} = \frac{e^z - e^{-z}}{e^z + e^{-z}} = \frac{2}{1 + e^{-2z}} - 1$$
# </div>
#
# * Derivative:
#
# <div style="font-size: 115%;">
# $$ \frac{d}{dz}tanh(z) = 1 - tanh^2(z)$$
# </div>

# %%
def tanh(z):
    return (np.e**z - np.e**(-z))/(np.e**z + np.e**(-z))

def D_tanh(z):
    return (1 - tanh(z)**2)

z = np.linspace(-5,5,100)
fig,(ax1,ax2) = plt.subplots(1,2)
ax1.plot(z,tanh(z))
ax1.set_title('tanh(z)')
ax2.plot(z,D_tanh(z))
ax2.set_title('Derivative of tanh');

# %% [markdown]
# * Scaled version of sigmoid: tanh(z)=2sigmoid(2z)-1
#
# * Range is (-1, 1), symmetric about the origin
#
# * Still have vanishing gradient problem

# %% [markdown]
# #### Rectified Linear Unit (ReLU)
#
# * Most popular activation function for hidden layers
#
# <div style="font-size: 115%;">
# $$ ReLU = max(0,z)$$
#
# $$ \frac{d}{dz}ReLU(z) = 1 \text{ if } z > 0 \text{ else } 0 $$
#
# </div>

# %%
def ReLU(z):
    return z * (z > 0)

def D_ReLU(z):
    return 1 * (z > 0)

z = np.linspace(-5,5,100)
fig,(ax1,ax2) = plt.subplots(1,2)
ax1.plot(z,ReLU(z))
ax1.set_title('ReLU(z)')
ax2.plot(z,D_ReLU(z))
ax2.set_title('Derivative of ReLU');

# %% [markdown]
# * Non-linear
#
# * It does not saturate for large positive values
#
# * Easy to compute
#
# * Derivative is 0 or 1
#     - If gradient = 1 then doesn't vanish when multiplied together
#     - If gradient = 0 then the weights will not be updated during backprop

# %% [markdown]
# #### Leaky ReLU
#
# * Improved version of ReLU, solves the problem of updating the weights for inputs less than zero
#      - Replaces the horizontal part of the function with a non-zero non-horizontal line
#
# <div style="font-size: 115%;">
# $$ LeakyReLU =  a*z \text{ if } z < 0 \text{ else } z$$
# $$ \frac{d}{dz}LeakyReLU(z) = 1 \text{ if } z > 0 \text{ else } a $$
# </div>

# %%
def L_ReLU(z, a = 0.01):
    return np.concatenate((a*z[z<0],z[z>= 0]))

def D_L_ReLU(z, a = 0.01):
    return np.concatenate((a * np.ones(len(z[z<0])), np.ones(len(z[z>= 0]))))

z = np.linspace(-5,5,20)
print(L_ReLU(z))
fig,(ax1,ax2) = plt.subplots(1,2)
ax1.plot(z,L_ReLU(z))
ax1.set_title('Leaky ReLU(z)')
ax2.plot(z,D_L_ReLU(z))
ax2.set_title('Derivative of Leaky ReLU');
# Out:
# [-5.00000000e-02 -4.47368421e-02 -3.94736842e-02 -3.42105263e-02
#  -2.89473684e-02 -2.36842105e-02 -1.84210526e-02 -1.31578947e-02
#  -7.89473684e-03 -2.63157895e-03  2.63157895e-01  7.89473684e-01
#   1.31578947e+00  1.84210526e+00  2.36842105e+00  2.89473684e+00
#   3.42105263e+00  3.94736842e+00  4.47368421e+00  5.00000000e+00]

# %% [markdown]
# #### Softmax
#
# * Multiclass
#
# * Outputs the probability that the input belongs to a particular class:
#
# #### for j = 1.2,...,k
#
# <div style="font-size: 115%;">
# $$ Softmax(z)_j =S(z)_j = \frac{e^{z_j}}{\sum_{k=1}^K e^{z_k}} $$
# </div>
#
# * Derivative
#
# $$\frac{d}{dz}S(z)_j = S(z)_j(\delta_{jk} - S(z)_k)$$
#
# $$ \delta \text{ is the Kronecker delta function}$$

# %%
z  = np.array([1.5,3.2,.75] )

def Softmax(z):
    ez = np.e**z
    return ez/np.sum(ez)
s = Softmax(z)
print(f'Softmax(z) = {s}')   
np.sum(s)
# Out:
# Softmax(z) = [0.14396124 0.78803628 0.06800248]
# 1.0

# %% [markdown]
# ### Backward Pass: Learning the weights
#
# * Calculate the Loss (i.e. Error, Cost) at the end of the forward pass and then propagate the error backwards though the layers to the input.
#
# * Changing (i.e. updating) the weights is the only way to affect the loss. We use gradient descent to update the weights in neural networks.
#
# * Gradient descent: Minimize the loss function by iteratively moving in the direction of the negative of the gradient.
#
# * Training the network: Repeat propagating the error backwards and adjusting the weights until the loss is within some tolerance.
#
# #### Loss Functions
#
# * Loss functions
#     - The function to be minimized during training
#     - Function of the output value and target value
#     - Cross-entropy loss (log loss): -(ylog(p) + (1-p)(log(1-p))
#         - measures the performance of a classification model that outputs a probability.
#         - increases as the predicted probability diverges from the actual label.

# %%
def CrossEntropy(yHat, y):
    if y == 1:
      return -log(yHat)
    else:
      return -log(1 - yHat)

# %% [markdown]
# #### Backpropagation and Gradient Descent
#
# * Three type of Gradient Descent
#     - **Batch** - Update all trials (observations) each epoch
#     - **Stochastic** - randomly select one observation to update each epoch
#     - **Mini Batch** - Choose a batch (e.g.32) observations to update each epoch

# %% [markdown]
# #### Optimizers
#
# * Stochastic Gradient Descent (SGD)
# * Adam

# %% [markdown]
# ### Mathematics of Backprop and gradient descent for a  simple Neural Network
#
# * For illustrative purposes using 1 Hidden layer of width 1 with sigmoid activation function for hidden and output layers
#
# ![](Simple_NN1.png)

# %% [markdown]
# Loss Function: L = $\frac{1}{2}(Y - y_{out})^2$
#
# Derivative of Loss Function: $D(L) = -(Y - y_{out})$
#
# Sigmoid Function: $\sigma(z) = \frac{1}{1 + e^{-z}}$
#
# Derivative of Sigmoid: $D(\sigma(z)) = \sigma(z)(1 - \sigma(z))$
#
# <div style="font-size: 125%;">
#
# $$h_{in} = X \cdot w_1,\text{ } h_{out} = \sigma(h_{in})$$
#
# $$y_{in} = h_{out} \cdot w_2,\text{ } y_{out} = \sigma(y_{in})$$
#
# </div>

# %% [markdown]
# #### Updating the weights (Gradient Descent)
#
# * $\gamma$ is the learning rate
#
# <div style="font-size: 125%;">
# $$ w_1^{(t)} = w_1^{(t-1)} - \gamma\frac{\partial{L}}{\partial{w_1^{(t-1)}}}$$
# $$ w_2^{(t)} = w_2^{(t-1)} - \gamma\frac{\partial{L}}{\partial{w_2^{(t-1)}}}$$
# </div>

# %% [markdown]
# #### Partial derivative of the Loss with respect to (wrt) the weights
#
# * Heavy use of chain rule
#
# * Weight for Output Layer
#
# <div style="font-size: 125%;">
# $$\frac{\partial{L}}{\partial{w_2}} = \frac{\partial{L}}{\partial{y_{out}}}\frac{\partial{y_{out}}}{\partial{y_{in}}} \frac{\partial{y_{in}}}{\partial{w_2}} = -(Y - y_{out})(y_{out}(1 - y_{out}))h_{out}$$
# </div>
#
# * Weight for Hidden Layer
#
# <div style="font-size: 125%;">
# $$\frac{\partial{L}}{\partial{w_1}} = \frac{\partial{L}}{\partial{y_{out}}}\frac{\partial{y_{out}}}{\partial{y_{in}}} \frac{\partial{y_{in}}}{\partial{h_{out}}} \frac{\partial{h_{out}}}{\partial{h_{in}}} \frac{\partial{h_{in}}}{\partial{w_1}} =  -(Y - y_{out})(y_{out}(1 - y_{out}))w_2(h_{out}(1 - h_{out}))X$$
# </div>

# %%
import numpy as np

# Activation functions and derivatives
#   Sigmoid or Logistic function
def Sigmoid(z):
    return 1/(1+np.exp(-z))
# Derivative of Sigmoid or Logistic function
def D_Sigmoid(z): 
    s = Sigmoid(z)
    return s * (1 - s)
#
# Loss Function
def Loss(y,yhat):
    return (1/2)*(y - yhat)**2

def D_Loss(y, yhat):
    return -(y - yhat)

# Dot Product
def Dot(x,w):
    return np.dot(x,w)

def D_Dot(x,w):
    return x

# %% [markdown]
# ![](Simple_NN1.png)

# %% [markdown]
# <div style="font-size: 115%;">
# $$\sigma(W_2\cdot{\sigma(W_1\cdot{X})})$$
#     </div>

# %%
def One_Epoch(w_1,w_2,X,Y):
    
    # Proprogate Forward
    h_in = Dot(X,w_1)
    h_out = Sigmoid(h_in)
    y_in = Dot(h_out,w_2)
    y_out = Sigmoid(y_in)
    
    # Backpropagation
        
    # Calculate the change in the error due to the weight in the second layer
        # D_Loss(Y, y_out) =  -(Y - y_out)* 
        # D_Sigmoid(y_in) =  (y_out(1 - y_out))
    delta_y = -(Y - y_out) * (y_out * (1 - y_out))
        # D_Dot(h_out,w_2) = h_out
    error_w2 = h_out.T.dot(delta_y) 
    #print(delta_y.shape,h_out.shape,error_w2.shape)
        # Calculate the change in the error due to the weight in weights in the first layer
        # D_Dot(w_2, y_in) = w_2   
        # D_Sigmoid(h_in) = h_out(1 - h_out) 
    delta_h = delta_y.dot(w_2.T) * (h_out * (1 - h_out))
        # D_Dot(X,w_1) = X       
    
    error_w1 = X.T.dot(delta_h)
    #print(delta_h.shape,X.shape,error_w1.shape)
    
    # Update weights
    w_2 = w_2 - gamma * error_w2
    w_1 = w_1 - gamma * error_w1
    return w_1,w_2, y_out

# %% [markdown]
# #### One sample,  three features, single output

# %% [markdown]
# ![](NN1.png)

# %%
np.random.seed(42)

# Data: 1 trial, 3 features
X = np.array([[.2, .4, .6]])
Y = np.array([[.8]])

# Weight Matricies
w_1 = 2*np.random.random((3,1)) - 1
w_2 = 2*np.random.random((1,1)) - 1

Max_Epoch = 2000
tolerance = 0.001 
gamma = 80
Converged = np.isclose(Y,0,tolerance)
cnt = 0

# %%
while (not Converged.all()) and (cnt < Max_Epoch):
    cnt += 1
    w_1,w_2,y = One_Epoch(w_1,w_2,X,Y)
    # Check if Converged
    Converged = np.isclose(Y,y,tolerance)
    
mse = np.mean((Y - y)**2) 
print(f"Output: {y} MSE: {mse}  Epoch {cnt}")
# Out:
# Output: [[0.79972594]] MSE: 7.510808053031572e-08  Epoch 5

# %% [markdown]
# ### Batch Gradient Descent

# %%
np.random.seed(42)
# 4 trials, 3 features
X = np.array([[.2, .4, .6],   
              [.3, .3, .1],
              [.5, .4, .7],
              [.8, .4, .1]])
N = X.shape[0]
Y = np.array([[.8],[.2], [.4], [.6]])
w_1 = 2*np.random.random((3,N)) - 1
w_2 = 2*np.random.random((N,1)) - 1

gamma = 50
tolerance = 0.001
Max_Epoch = 40000
Converged = np.isclose(Y,0)
cnt = 0 

while (not Converged.all()) and (cnt < Max_Epoch):
    cnt += 1
    w_1,w_2,y = One_Epoch(w_1,w_2,X,Y)
    # Check if Converged
    Converged = np.isclose(Y,y,tolerance)
    
mse = np.mean((Y - y)**2) 
print(f"Output: \n {y} \n \n MSE: {mse}  Epoch {cnt}")
# Out:
# Output:
#  [[0.79373419]
#  [0.19945959]
#  [0.3979039 ]
#  [0.49987771]]
#
#  MSE: 0.002517104514160813  Epoch 40000

# %% [markdown]
# ### Stochastic Gradient Descent

# %%
np.random.seed(42)
trials = np.random.permutation(range(4))
print("Trials: ", trials)

Data = np.array([[.2, .4, .6],
              [.3, .3, .1],
              [.5, .4, .7],
              [.8, .4, .1]])

Labels = np.array([[.8],[.2], [.4], [.6]])

w_1 = 2*np.random.random((3,1)) - 1
w_2 = 2*np.random.random((1,1)) - 1

gamma = 80

for tr in trials:
    X = Data[tr,:].reshape(1,-1)
    Y = Labels[tr,:].reshape(1,1)
    
    tolerance = 0.001
    Max_Epoch = 40000
    Converged = np.isclose(Y,0)
    cnt = 0 

    while (not Converged.all()) and (cnt < Max_Epoch):
        cnt += 1
        w_1,w_2,y = One_Epoch(w_1,w_2,X,Y)
        # Check if Converged
        Converged = np.isclose(Y,y,tolerance)
    
    mse = np.mean((Y - y)**2) 
    print(f"Trial {tr} \n Output: \n {y} \n \n MSE: {mse}  Epoch {cnt}")
# Out:
# Trials:  [1 3 0 2]
# Trial 1
#  Output:
#  [[0.19982821]]
#
#  MSE: 2.9513485603408573e-08  Epoch 6
# Trial 3
#  Output:
#  [[0.59968831]]
#
#  MSE: 9.715333813531401e-08  Epoch 12
# Trial 0
#  Output:
#  [[0.79972496]]
#
#  MSE: 7.564683865524363e-08  Epoch 4
# Trial 2
#  Output:
#  [[0.40035745]]
#
#  MSE: 1.2776733257236824e-07  Epoch 55

# %% [markdown]
# ### MultiLayerPerceptron (MLP) Logistic Regression
#
# http://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html

# %%
# Importing the dataset

import sys
if 'google.colab' in sys.modules:
    from google.colab import files
    uploaded = files.upload()
ads = pd.read_csv('knn_data.csv')
ads.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X = ads.loc[:, ["Age","EstimatedSalary"]].values
y = ads.loc[:, "Purchased"].values

# %%
# Splitting the dataset into the Training set and Test set

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size = 0.25, random_state = 1)

# Feature Scaling

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Fitting model to the Training set

model = MLPClassifier(solver='lbfgs', activation = 'logistic' ,hidden_layer_sizes=(2), random_state=123)
model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=2, random_state=123,
#               solver='lbfgs')

# %%
print("Score: ",model.score(X_test,y_test))

# Predicting the Test set results
y_pred = model.predict(X_test)

# Making the Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# Score:  0.9
# array([[58,  6],
#        [ 4, 32]])

# %% [markdown]
# #### Plot Classification Surface

# %%
from matplotlib.colors import ListedColormap
def classification_plot(X_data,y_data,model,ax):
    # Make grid: min to max of 1st column, min to max of 2nd column in small increments
    X1,X2 = np.meshgrid(np.arange(X_data[:, 0].min() - 1, X_data[:, 0].max() + 1, step = 0.01),
                        np.arange(X_data[:, 1].min() - 1, X_data[:, 1].max() + 1, step = 0.01))
    v = np.array([X1.ravel(), X2.ravel()]).T # Flatten the features X1 and X2
    #  Using fitted model, predict the points in the grid and reshape to a 2-dimensional array
    ax.contourf(X1, X2, model.predict(v).reshape(X1.shape),alpha = 0.75, cmap = ListedColormap(('magenta', 'cyan')))
    ax.set_xlim(X1.min(), X1.max())
    ax.set_ylim(X2.min(), X2.max())
    for i, y in enumerate(np.unique(y_data)): # For each class,plot the true points
        ax.scatter(X_data[y_data == y, 0], X_data[y_data == y, 1],
                   c = np.array(ListedColormap(('white', 'black'))(i)).reshape(1,-1), label = y)

# %%
# Plot Results
fig,(ax1,ax2)=plt.subplots(1,2,figsize = (10,6))

# Visualising the Training set results
classification_plot(X_train,y_train,model, ax1)
ax1.set_title('Training Data')
ax1.set_xlabel('Age')
ax1.set_ylabel('Salary')
ax1.legend()

# Visualising the Test set results
classification_plot(X_test,y_test, model, ax2)
ax2.set_title('Test Data')
ax2.set_xlabel('Age')
ax2.set_ylabel('Salary')
ax2.legend();
# Out:
# (363573, 2) (609, 597) (609, 597)
# (609, 597)
# (358092, 2) (609, 588) (609, 588)
# (609, 588)

# %% [markdown]
# #### Use defaults

# %%
model = MLPClassifier(random_state=123) ## Use all defaults
model.fit(X_train, y_train) 
print("Score: ",model.score(X_test,y_test))
y_pred = model.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# Score:  0.89
# array([[57,  7],
#        [ 4, 32]])

# %%
model.get_params()
# Out:
# {'activation': 'relu',
#  'alpha': 0.0001,
#  'batch_size': 'auto',
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'early_stopping': False,
#  'epsilon': 1e-08,
#  'hidden_layer_sizes': (100,),
#  'learning_rate': 'constant',
#  'learning_rate_init': 0.001,
#  'max_iter': 200,
#  'momentum': 0.9,
#  'n_iter_no_change': 10,
#  'nesterovs_momentum': True,
#  'power_t': 0.5,
#  'random_state': 123,
#  'shuffle': True,
#  'solver': 'adam',
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': False,
#  'warm_start': False}

# %%
# Plot Results
fig,(ax1,ax2)=plt.subplots(1,2,figsize = (10,6))

# Visualising the Training set results
classification_plot(X_train,y_train,model, ax1)
ax1.set_title('Training Data')
ax1.set_xlabel('Age')
ax1.set_ylabel('Salary')
ax1.legend()

# Visualising the Test set results
classification_plot(X_test,y_test, model, ax2)
ax2.set_title('Test Data')
ax2.set_xlabel('Age')
ax2.set_ylabel('Salary')
ax2.legend();

# %% [markdown]
# ### MLP for Multinomial Logistic Regression

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species');

# %% [markdown]
# #### Data Preprocessing

# %%
# Covert to arrays
X = iris.iloc[:,0:2].values
y = iris.iloc[:,4].values

# Train/Test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y,random_state = 1234)

# Scale Data
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# #### Fit Model

# %%
model = MLPClassifier(solver='lbfgs',activation = 'logistic' ,hidden_layer_sizes=(2), random_state=1)

model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=2, learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %% [markdown]
# #### Predict Test Set

# %%
print("Score: ",model.score(X_test,y_test))

# Predicting the Test set results
y_pred = model.predict(X_test)

# Making the Confusion Matrix

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# Score:  0.8
# array([[10,  0,  0],
#        [ 0,  6,  4],
#        [ 0,  2,  8]])

# %% [markdown]
# ## Pytorch

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

# %%
# Splitting the dataset into the Training set and Test set

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size = 0.25, random_state = 1)

# Feature Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Convert data into torch tensors
X_train_t = torch.from_numpy(X_train.astype(np.float32)).to(device)
X_test_t = torch.from_numpy(X_test.astype(np.float32)).to(device)
y_train_t = torch.from_numpy(y_train.astype(np.float32).reshape(-1, 1)).to(device)
y_test_t = torch.from_numpy(y_test.astype(np.float32).reshape(-1, 1)).to(device)

# %%
torch.manual_seed(1)

# Create the classification model class, loss and optimizer

class LogRegress(nn.Module):
    def __init__(self,num_in,num_out):
        super(LogRegress, self).__init__() 
        self.linear = torch.nn.Linear(num_in, num_out)  
        self.sigmoid = nn.Sigmoid()
  
    def forward(self, x): 
        y_pred = F.relu(self.linear(x)) 
        return self.sigmoid(y_pred) 
    
model = LogRegress(X_train.shape[1],1)
model.to(device) # Send to device before specifing optimizer

# %%
# Loss and optimizer
criterion = nn.BCELoss() #Bineary Cross Entropy
optimizer = torch.optim.Adam(model.parameters())

# %%
loss.item()
# Out:
# 0.6138697862625122

# %%
# Train the model
n_epochs = 1000

# Stuff to store
train_losses = np.zeros(n_epochs)
test_losses = np.zeros(n_epochs)

for it in range(n_epochs):
  
  optimizer.zero_grad() # zero the parameter gradients

  outputs = model(X_train_t) # Forward pass via __call__, outputs is a tensor
    
  loss = criterion(outputs, y_train_t) # Calculate the loss
    
  loss.backward() # Computes the Gradients
  optimizer.step() # Updates the weights

  # Get test loss
  outputs_test = model(X_test_t)
  loss_test = criterion(outputs_test, y_test_t)

  # Save losses
  train_losses[it] = loss.item()
  test_losses[it] = loss_test.item()
    
  if (it + 1) % 50 == 0:
    print(f'Epoch {it+1}/{n_epochs}, Train Loss: {loss.item():.4f}, Test Loss: {loss_test.item():.4f}')
# Out:
# Epoch 50/1000, Train Loss: 0.6640, Test Loss: 0.6618
# Epoch 100/1000, Train Loss: 0.6582, Test Loss: 0.6585
# Epoch 150/1000, Train Loss: 0.6530, Test Loss: 0.6534
# Epoch 200/1000, Train Loss: 0.6483, Test Loss: 0.6488
# Epoch 250/1000, Train Loss: 0.6439, Test Loss: 0.6457
# Epoch 300/1000, Train Loss: 0.6398, Test Loss: 0.6435
# Epoch 350/1000, Train Loss: 0.6355, Test Loss: 0.6419
# Epoch 400/1000, Train Loss: 0.6313, Test Loss: 0.6402
# Epoch 450/1000, Train Loss: 0.6279, Test Loss: 0.6387
# Epoch 500/1000, Train Loss: 0.6254, Test Loss: 0.6373
# Epoch 550/1000, Train Loss: 0.6233, Test Loss: 0.6363
# Epoch 600/1000, Train Loss: 0.6215, Test Loss: 0.6356
# Epoch 650/1000, Train Loss: 0.6200, Test Loss: 0.6352
# Epoch 700/1000, Train Loss: 0.6188, Test Loss: 0.6347
# Epoch 750/1000, Train Loss: 0.6177, Test Loss: 0.6345
# Epoch 800/1000, Train Loss: 0.6168, Test Loss: 0.6342
# Epoch 850/1000, Train Loss: 0.6160, Test Loss: 0.6341
# Epoch 900/1000, Train Loss: 0.6152, Test Loss: 0.6344
# Epoch 950/1000, Train Loss: 0.6145, Test Loss: 0.6344
# Epoch 1000/1000, Train Loss: 0.6139, Test Loss: 0.6347

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

# %%
# Get accuracy
with torch.no_grad():
  p_train = model(X_train_t)
  p_train = np.round(p_train.numpy())
  train_acc = np.mean(y_train_t.numpy() == p_train)

  p_test = model(X_test_t)
  p_test = np.round(p_test.numpy())
  test_acc = np.mean(y_test_t.numpy() == p_test)
print(f"Train acc: {train_acc:.4f}, Test acc: {test_acc:.4f}")
# Out:
# Train acc: 0.8200, Test acc: 0.8600

# %%
type(y_test),type(y_test_t)
# Out:
# (numpy.ndarray, torch.Tensor)

# %%
cm = confusion_matrix(y_test_t, p_test)
cm
# Out:
# array([[53, 11],
#        [ 3, 33]])

# %%
from matplotlib.colors import ListedColormap
def torch_plot(X_data,y_data,model,ax):
    # Make grid: min to max of 1st column, min to max of 2nd column in small increments
    X1,X2 = np.meshgrid(np.arange(X_data[:, 0].min() - 1, X_data[:, 0].max() + 1, step = 0.01),
                     np.arange(X_data[:, 1].min() - 1, X_data[:, 1].max() + 1, step = 0.01))
    # Flatten X1 and X2, create an array and transpose to a 2-column array (one for each feature)
    v = np.array([X1.ravel(), X2.ravel()]).T
    v = torch.from_numpy(v.astype(np.float32))
    v_ = model(v) #  Using fitted model, predict the points in v 
    ax.contourf(X1, X2, v_.detach().numpy().reshape(X1.shape),alpha = 0.75, cmap = ListedColormap(('magenta', 'cyan')))
    ax.set_xlim(X1.min(), X1.max())
    ax.set_ylim(X2.min(), X2.max())
    for i, j in enumerate(np.unique(y_data)):
        ax.scatter(X_data[y_data == j, 0], X_data[y_data == j, 1],
                c = np.array(ListedColormap(('white', 'black'))(i)).reshape(1,-1), label = j)

# %%
# Plot Results
fig,(ax1,ax2)=plt.subplots(1,2,figsize = (10,6))

# Visualising the Training set results
torch_plot(X_train,y_train,model, ax1)
ax1.set_title('Training Data')
ax1.set_xlabel('Age')
ax1.set_ylabel('Salary')
ax1.legend()

# Visualising the Test set results
torch_plot(X_test,y_test, model, ax2)
ax2.set_title('Test Data')
ax2.set_xlabel('Age')
ax2.set_ylabel('Salary')
ax2.legend();
