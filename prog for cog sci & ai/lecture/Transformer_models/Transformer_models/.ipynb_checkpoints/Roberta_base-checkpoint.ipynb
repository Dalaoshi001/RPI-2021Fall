# %% [markdown]
# https://huggingface.co/roberta-base

# %%
# %%capture
# !pip install transformers

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
  
tokenizer = AutoTokenizer.from_pretrained("roberta-base")

model = AutoModelForMaskedLM.from_pretrained("roberta-base")
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]

# %%
from transformers import pipeline
unmasker = pipeline('fill-mask', model='roberta-base')
unmasker("Hello I'm a <mask> model.")
# Out:
# [{'score': 0.33065277338027954,
#   'sequence': "Hello I'm a male model.",
#   'token': 2943,
#   'token_str': ' male'},
#  {'score': 0.046553999185562134,
#   'sequence': "Hello I'm a female model.",
#   'token': 2182,
#   'token_str': ' female'},
#  {'score': 0.04232997074723244,
#   'sequence': "Hello I'm a professional model.",
#   'token': 2038,
#   'token_str': ' professional'},
#  {'score': 0.03721674904227257,
#   'sequence': "Hello I'm a fashion model.",
#   'token': 2734,
#   'token_str': ' fashion'},
#  {'score': 0.0325365848839283,
#   'sequence': "Hello I'm a Russian model.",
#   'token': 1083,
#   'token_str': ' Russian'}]

# %%
unmasker("Hello she is a going to <mask>.")
# Out:
# [{'score': 0.0855724960565567,
#   'sequence': 'Hello she is a going to visit.',
#   'token': 825,
#   'token_str': ' visit'},
#  {'score': 0.03983853757381439,
#   'sequence': 'Hello she is a going to talk.',
#   'token': 1067,
#   'token_str': ' talk'},
#  {'score': 0.036500658839941025,
#   'sequence': 'Hello she is a going to school.',
#   'token': 334,
#   'token_str': ' school'},
#  {'score': 0.03140491619706154,
#   'sequence': 'Hello she is a going to speak.',
#   'token': 1994,
#   'token_str': ' speak'},
#  {'score': 0.029220610857009888,
#   'sequence': 'Hello she is a going to be.',
#   'token': 28,
#   'token_str': ' be'}]
